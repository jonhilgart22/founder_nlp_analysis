# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import numpy as np
import textblob
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import os
from os.path import isfile, join
from os import listdir
import pickle
import pandas as pd

# %%
doc_a = "Brocolli is good to eat. My brother likes to eat good brocolli, but not my mother. It helps you with heart problems."
doc_b = "My mother spends a lot of time driving my brother around to baseball practice. Baseball if one of my brothers favorite activities"
doc_c = "Some health experts suggest that driving may cause increased tension and blood pressure. Also, driving may cause skin cancer."
doc_d = "I often feel pressure to perform well at school, but my mother never seems to drive my brother to do better."
doc_e = "Health professionals say that brocolli is good for your health. It can also counter the negatives of stress."

# compile sample documents into a list
doc_set = [doc_a, doc_b, doc_c, doc_d, doc_e]

# %%
blob  = textblob.blob.TextBlob("".join(doc_set)) # tokenize the blob

# %%
blob.tokenize()
# Out:
# WordList(['Brocolli', 'is', 'good', 'to', 'eat', '.', 'My', 'brother', 'likes', 'to', 'eat', 'good', 'brocolli', ',', 'but', 'not', 'my', 'mother', '.', 'It', 'helps', 'you', 'with', 'heart', 'problems.My', 'mother', 'spends', 'a', 'lot', 'of', 'time', 'driving', 'my', 'brother', 'around', 'to', 'baseball', 'practice', '.', 'Baseball', 'if', 'one', 'of', 'my', 'brothers', 'favorite', 'activitiesSome', 'health', 'experts', 'suggest', 'that', 'driving', 'may', 'cause', 'increased', 'tension', 'and', 'blood', 'pressure', '.', 'Also', ',', 'driving', 'may', 'cause', 'skin', 'cancer.I', 'often', 'feel', 'pressure', 'to', 'perform', 'well', 'at', 'school', ',', 'but', 'my', 'mother', 'never', 'seems', 'to', 'drive', 'my', 'brother', 'to', 'do', 'better.Health', 'professionals', 'say', 'that', 'brocolli', 'is', 'good', 'for', 'your', 'health', '.', 'It', 'can', 'also', 'counter', 'the', 'negatives', 'of', 'stress', '.'])

# %%
no_features=1000

# %%
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=1, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(doc_set)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
tf
# Out:
# <5x38 sparse matrix of type '<class 'numpy.int64'>'
# 	with 47 stored elements in Compressed Sparse Row format>

# %%
tf_feature_names
# Out:
# ['activities',
#  'baseball',
#  'better',
#  'blood',
#  'brocolli',
#  'brother',
#  'brothers',
#  'cancer',
#  'cause',
#  'counter',
#  'drive',
#  'driving',
#  'eat',
#  'experts',
#  'favorite',
#  'feel',
#  'good',
#  'health',
#  'heart',
#  'helps',
#  'increased',
#  'likes',
#  'lot',
#  'mother',
#  'negatives',
#  'perform',
#  'practice',
#  'pressure',
#  'problems',
#  'professionals',
#  'say',
#  'school',
#  'skin',
#  'spends',
#  'stress',
#  'suggest',
#  'tension',
#  'time']

# %%
lda_model = LatentDirichletAllocation(n_topics=3, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
lda_W = lda_model.transform(tf) # documents as the rows, topics as the columns
lda_H = lda_model.components_ # topics as the rows, words as the columns

# %%
lda_W
# Out:
# array([[ 0.02908081,  0.94264018,  0.02827901],
#        [ 0.02893521,  0.94213988,  0.02892491],
#        [ 0.02695629,  0.02646135,  0.94658236],
#        [ 0.0416116 ,  0.91698643,  0.04140197],
#        [ 0.92633112,  0.03686845,  0.03680043]])

# %%
lda_H[0]
# Out:
# array([ 0.95211094,  0.84706215,  0.96155505,  0.74732936,  1.08121608,
#         0.8494759 ,  0.8734277 ,  0.82473556,  0.85012361,  1.11074376,
#         0.93095234,  0.80411069,  0.64691762,  0.86434555,  0.99410168,
#         0.71602261,  1.20676853,  1.4730662 ,  0.75393777,  0.68147528,
#         0.9095761 ,  0.90751579,  0.74243208,  0.71969034,  1.04923259,
#         0.78538113,  0.70509772,  0.80305647,  0.753064  ,  1.11442345,
#         1.08382812,  0.84827887,  0.77094035,  0.78994215,  1.02729989,
#         0.69760789,  0.70406667,  0.85035124])

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
no_top_words = 10

display_topics(lda_model, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# health good professionals counter say brocolli negatives stress favorite better
# Topic 1:
# mother brother good baseball brocolli eat lot spends school pressure
# Topic 2:
# cause driving experts cancer suggest blood skin tension increased stress

# %%
def display_topics(H, W, feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print (f'DOC {doc_index}:',documents[doc_index])

# %%
no_top_words = 5
no_top_documents = 2
display_topics(lda_H, lda_W, tf_feature_names, doc_set, no_top_words, no_top_documents)
# Out:
# Topic 0:
# health good professionals counter say
# DOC 4: Health professionals say that brocolli is good for your health. It can also counter the negatives of stress.
# DOC 3: I often feel pressure to perform well at school, but my mother never seems to drive my brother to do better.
# Topic 1:
# mother brother good baseball brocolli
# DOC 0: Brocolli is good to eat. My brother likes to eat good brocolli, but not my mother. It helps you with heart problems.
# DOC 1: My mother spends a lot of time driving my brother around to baseball practice. Baseball if one of my brothers favorite activities
# Topic 2:
# cause driving experts cancer suggest
# DOC 2: Some health experts suggest that driving may cause increased tension and blood pressure. Also, driving may cause skin cancer.
# DOC 3: I often feel pressure to perform well at school, but my mother never seems to drive my brother to do better.

# %%
def display_percent_of_each_topic(lda_W, model, feature_names, no_top_words):
    """Print out the percent of each topic, along with the top five words from each topic.
    
    """
    for topic_idx, topic in enumerate(lda_W):
        print(f"""Document {topic_idx} has the following percent of each topic 1 =  {topic[0]:.2%},\
        topic 2 = {topic[1]:.2%}, topic 3 = {topic[2]:.2%}""")
        
    print()
    print('Topics')
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
return_percent_of_topic

# %%
lda_W[1]
# Out:
# array([ 0.00606061,  0.00606061,  0.00606061,  0.00606061,  0.00606061,
#         0.00606061,  0.00606061,  0.00606061,  0.00606061,  0.00606061,
#         0.00606061,  0.00606061,  0.00606061,  0.91515152,  0.00606061])

# %%
display_percent_of_each_topic(lda_W,lda_model,tf_feature_names, 10)
# Out:
# Document 0 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 1 has the following percent of each topic 1 =  0.61%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 2 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 3 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 4 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 5 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 6 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 7 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 8 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 9 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 10 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 81.33%
# Document 11 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 12 has the following percent of each topic 1 =  35.56%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 13 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 14 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 15 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 16 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 17 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 18 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 19 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 20 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 21 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 22 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 23 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 24 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 25 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 26 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 27 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 28 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 29 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 30 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 31 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 32 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 33 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 34 has the following percent of each topic 1 =  0.67%,        topic 2 = 0.67%, topic 3 = 0.67%
# Document 35 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 36 has the following percent of each topic 1 =  29.52%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 37 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 38 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 39 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 40 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 41 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 42 has the following percent of each topic 1 =  10.67%,        topic 2 = 0.67%, topic 3 = 0.67%
# Document 43 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 44 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 45 has the following percent of each topic 1 =  1.33%,        topic 2 = 61.33%, topic 3 = 1.33%
# Document 46 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 47 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 48 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 49 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 50 has the following percent of each topic 1 =  0.67%,        topic 2 = 0.67%, topic 3 = 0.67%
# Document 51 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 52 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 53 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 54 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 55 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 56 has the following percent of each topic 1 =  1.11%,        topic 2 = 84.44%, topic 3 = 1.11%
# Document 57 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 58 has the following percent of each topic 1 =  1.11%,        topic 2 = 17.78%, topic 3 = 1.11%
# Document 59 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 60 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 61 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 62 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 63 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 64 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 65 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 66 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 67 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 68 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 69 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 70 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 71 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 72 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 73 has the following percent of each topic 1 =  1.11%,        topic 2 = 67.78%, topic 3 = 1.11%
# Document 74 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 75 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 76 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 77 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 78 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 79 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 80 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 81 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 82 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 83 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 84 has the following percent of each topic 1 =  2.22%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 85 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 86 has the following percent of each topic 1 =  2.22%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 87 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 88 has the following percent of each topic 1 =  67.41%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 89 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 90 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 91 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 92 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 93 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 94 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 95 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 96 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 97 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 98 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 99 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 100 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 101 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 102 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 103 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 104 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 105 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 106 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 107 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 108 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 109 has the following percent of each topic 1 =  84.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 110 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 111 has the following percent of each topic 1 =  68.89%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 112 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 113 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 114 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 115 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 116 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 117 has the following percent of each topic 1 =  9.70%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 118 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 119 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 120 has the following percent of each topic 1 =  0.83%,        topic 2 = 50.83%, topic 3 = 0.83%
# Document 121 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 122 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 123 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 124 has the following percent of each topic 1 =  2.22%,        topic 2 = 68.89%, topic 3 = 2.22%
# Document 125 has the following percent of each topic 1 =  1.11%,        topic 2 = 67.78%, topic 3 = 17.78%
# Document 126 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 127 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 128 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 129 has the following percent of each topic 1 =  76.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 130 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 131 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 132 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 133 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 134 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 81.33%
# Document 135 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 15.24%
# Document 136 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 13.33%
# Document 137 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 138 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 139 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 140 has the following percent of each topic 1 =  53.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 141 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 142 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 143 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 144 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 145 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 146 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 147 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 148 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 149 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 150 has the following percent of each topic 1 =  0.95%,        topic 2 = 15.24%, topic 3 = 0.95%
# Document 151 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 152 has the following percent of each topic 1 =  21.33%,        topic 2 = 21.33%, topic 3 = 1.33%
# Document 153 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 154 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 155 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 156 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 157 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 158 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 159 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 160 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 68.89%
# Document 161 has the following percent of each topic 1 =  25.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 162 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 163 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 164 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 165 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 166 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 167 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 168 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 169 has the following percent of each topic 1 =  25.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 170 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 171 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 172 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 173 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 174 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 175 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 176 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 177 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 178 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 179 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 180 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 181 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 182 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 183 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 184 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 185 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 186 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 187 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 188 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 189 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 190 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 191 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 192 has the following percent of each topic 1 =  18.79%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 193 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 68.89%
# Document 194 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 195 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 196 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 197 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 198 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 199 has the following percent of each topic 1 =  7.62%,        topic 2 = 0.48%, topic 3 = 0.48%
# Document 200 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 201 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 202 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 203 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 204 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 205 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 67.78%
# Document 206 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 207 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 208 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 209 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 210 has the following percent of each topic 1 =  0.61%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 211 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 212 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 213 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 214 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 215 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 25.83%
# Document 216 has the following percent of each topic 1 =  2.22%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 217 has the following percent of each topic 1 =  27.88%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 218 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 219 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 220 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 221 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 222 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 223 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 29.52%
# Document 224 has the following percent of each topic 1 =  34.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 225 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 226 has the following percent of each topic 1 =  25.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 227 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 228 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 229 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 230 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 76.67%
# Document 231 has the following percent of each topic 1 =  11.85%,        topic 2 = 11.85%, topic 3 = 0.74%
# Document 232 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 233 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 234 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 235 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 236 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 237 has the following percent of each topic 1 =  0.74%,        topic 2 = 67.41%, topic 3 = 11.85%
# Document 238 has the following percent of each topic 1 =  0.83%,        topic 2 = 50.83%, topic 3 = 25.83%
# Document 239 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 68.89%
# Document 240 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 241 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 242 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 243 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 244 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 245 has the following percent of each topic 1 =  53.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 246 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 247 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 248 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 249 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 250 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 63.33%
# Document 251 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 252 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 253 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 254 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 78.52%
# Document 255 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 256 has the following percent of each topic 1 =  38.33%,        topic 2 = 50.83%, topic 3 = 0.83%
# Document 257 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 258 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 259 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 260 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 261 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 262 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 263 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 264 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 265 has the following percent of each topic 1 =  0.74%,        topic 2 = 11.85%, topic 3 = 11.85%
# Document 266 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 267 has the following percent of each topic 1 =  1.67%,        topic 2 = 26.67%, topic 3 = 1.67%
# Document 268 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 269 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 270 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 271 has the following percent of each topic 1 =  0.61%,        topic 2 = 0.61%, topic 3 = 46.06%
# Document 272 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 273 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 26.67%
# Document 274 has the following percent of each topic 1 =  0.95%,        topic 2 = 72.38%, topic 3 = 0.95%
# Document 275 has the following percent of each topic 1 =  1.67%,        topic 2 = 26.67%, topic 3 = 51.67%
# Document 276 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 277 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 278 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 279 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 280 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 29.52%
# Document 281 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 72.38%
# Document 282 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 283 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 284 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 285 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 286 has the following percent of each topic 1 =  1.33%,        topic 2 = 21.33%, topic 3 = 41.33%
# Document 287 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 288 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 289 has the following percent of each topic 1 =  1.11%,        topic 2 = 51.11%, topic 3 = 1.11%
# Document 290 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 291 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 292 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 293 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 294 has the following percent of each topic 1 =  38.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 295 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 29.52%
# Document 296 has the following percent of each topic 1 =  1.33%,        topic 2 = 41.33%, topic 3 = 1.33%
# Document 297 has the following percent of each topic 1 =  1.33%,        topic 2 = 41.33%, topic 3 = 1.33%
# Document 298 has the following percent of each topic 1 =  72.38%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 299 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 300 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 301 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 302 has the following percent of each topic 1 =  58.10%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 303 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 304 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 305 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 306 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 307 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 308 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 15.24%
# Document 309 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 310 has the following percent of each topic 1 =  9.70%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 311 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 312 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 313 has the following percent of each topic 1 =  50.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 314 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 29.52%
# Document 315 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 316 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 13.33%
# Document 317 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 318 has the following percent of each topic 1 =  0.67%,        topic 2 = 0.67%, topic 3 = 40.67%
# Document 319 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 320 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 321 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 322 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 323 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 324 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 325 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 326 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 327 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 34.44%
# Document 328 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 329 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 330 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 331 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 332 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 333 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 11.85%
# Document 334 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 15.24%
# Document 335 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 336 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 337 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 338 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 339 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 340 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 341 has the following percent of each topic 1 =  1.33%,        topic 2 = 21.33%, topic 3 = 21.33%
# Document 342 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 343 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 344 has the following percent of each topic 1 =  0.61%,        topic 2 = 0.61%, topic 3 = 0.61%
# Document 345 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 346 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 45.19%
# Document 347 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 348 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 349 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 350 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 51.67%
# Document 351 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 352 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 353 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 354 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 355 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 26.67%
# Document 356 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 357 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 358 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 359 has the following percent of each topic 1 =  0.95%,        topic 2 = 43.81%, topic 3 = 0.95%
# Document 360 has the following percent of each topic 1 =  2.22%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 361 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 362 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 363 has the following percent of each topic 1 =  0.61%,        topic 2 = 0.61%, topic 3 = 18.79%
# Document 364 has the following percent of each topic 1 =  41.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 365 has the following percent of each topic 1 =  76.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 366 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 367 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 51.11%
# Document 368 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 369 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 370 has the following percent of each topic 1 =  29.52%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 371 has the following percent of each topic 1 =  1.67%,        topic 2 = 51.67%, topic 3 = 1.67%
# Document 372 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 373 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 374 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 375 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 376 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 377 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 378 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 379 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 380 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 381 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 382 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 383 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 384 has the following percent of each topic 1 =  13.33%,        topic 2 = 0.83%, topic 3 = 63.33%
# Document 385 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 386 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 387 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 388 has the following percent of each topic 1 =  0.67%,        topic 2 = 20.67%, topic 3 = 30.67%
# Document 389 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 390 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 391 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 392 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 393 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 394 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 395 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 396 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 397 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 398 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 399 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 400 has the following percent of each topic 1 =  1.33%,        topic 2 = 21.33%, topic 3 = 1.33%
# Document 401 has the following percent of each topic 1 =  34.44%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 402 has the following percent of each topic 1 =  1.33%,        topic 2 = 41.33%, topic 3 = 1.33%
# Document 403 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 404 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 405 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 406 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 407 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 408 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 409 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 410 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 411 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 412 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 413 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 414 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 415 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 416 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 51.11%
# Document 417 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 418 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 419 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 420 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 421 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 422 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 423 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 424 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 425 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 426 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 427 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 428 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 429 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 43.81%
# Document 430 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 431 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 432 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 433 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 434 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 435 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 436 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 437 has the following percent of each topic 1 =  1.33%,        topic 2 = 81.33%, topic 3 = 1.33%
# Document 438 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 439 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 440 has the following percent of each topic 1 =  0.95%,        topic 2 = 29.52%, topic 3 = 0.95%
# Document 441 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 442 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 443 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 51.67%
# Document 444 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 445 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 446 has the following percent of each topic 1 =  0.95%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 447 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 448 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 68.89%
# Document 449 has the following percent of each topic 1 =  15.24%,        topic 2 = 0.95%, topic 3 = 0.95%
# Document 450 has the following percent of each topic 1 =  1.67%,        topic 2 = 51.67%, topic 3 = 1.67%
# Document 451 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 452 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 453 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 454 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 455 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# ...
# Document 18087 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18088 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18089 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18090 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 26.67%
# Document 18091 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18092 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18093 has the following percent of each topic 1 =  53.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18094 has the following percent of each topic 1 =  68.89%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18095 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18096 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18097 has the following percent of each topic 1 =  21.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 18098 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 18099 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18100 has the following percent of each topic 1 =  35.56%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 18101 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 18102 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18103 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18104 has the following percent of each topic 1 =  8.89%,        topic 2 = 0.56%, topic 3 = 0.56%
# Document 18105 has the following percent of each topic 1 =  68.89%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18106 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18107 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18108 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 18109 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 18110 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18111 has the following percent of each topic 1 =  0.67%,        topic 2 = 10.67%, topic 3 = 0.67%
# Document 18112 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18113 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18114 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 41.33%
# Document 18115 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 18116 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 17.78%
# Document 18117 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 18118 has the following percent of each topic 1 =  0.83%,        topic 2 = 13.33%, topic 3 = 0.83%
# Document 18119 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 18120 has the following percent of each topic 1 =  41.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 18121 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18122 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 18123 has the following percent of each topic 1 =  0.74%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 18124 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 18125 has the following percent of each topic 1 =  38.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 18126 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 1.33%
# Document 18127 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18128 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18129 has the following percent of each topic 1 =  38.33%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 18130 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 18131 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18132 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 34.44%
# Document 18133 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18134 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18135 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18136 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18137 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18138 has the following percent of each topic 1 =  53.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18139 has the following percent of each topic 1 =  17.78%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18140 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18141 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18142 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18143 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18144 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18145 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18146 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18147 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18148 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18149 has the following percent of each topic 1 =  1.67%,        topic 2 = 26.67%, topic 3 = 1.67%
# Document 18150 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18151 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 26.67%
# Document 18152 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 18153 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18154 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 18155 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18156 has the following percent of each topic 1 =  2.22%,        topic 2 = 68.89%, topic 3 = 2.22%
# Document 18157 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18158 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 18159 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18160 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18161 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18162 has the following percent of each topic 1 =  0.95%,        topic 2 = 29.52%, topic 3 = 0.95%
# Document 18163 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18164 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18165 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18166 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18167 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18168 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18169 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18170 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18171 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18172 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18173 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18174 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18175 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18176 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18177 has the following percent of each topic 1 =  1.11%,        topic 2 = 34.44%, topic 3 = 1.11%
# Document 18178 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 0.83%
# Document 18179 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18180 has the following percent of each topic 1 =  1.33%,        topic 2 = 41.33%, topic 3 = 1.33%
# Document 18181 has the following percent of each topic 1 =  1.67%,        topic 2 = 51.67%, topic 3 = 1.67%
# Document 18182 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18183 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 53.33%
# Document 18184 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18185 has the following percent of each topic 1 =  26.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18186 has the following percent of each topic 1 =  35.56%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18187 has the following percent of each topic 1 =  0.83%,        topic 2 = 0.83%, topic 3 = 25.83%
# Document 18188 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18189 has the following percent of each topic 1 =  35.56%,        topic 2 = 35.56%, topic 3 = 2.22%
# Document 18190 has the following percent of each topic 1 =  11.85%,        topic 2 = 0.74%, topic 3 = 0.74%
# Document 18191 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18192 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 18193 has the following percent of each topic 1 =  0.67%,        topic 2 = 20.67%, topic 3 = 0.67%
# Document 18194 has the following percent of each topic 1 =  6.67%,        topic 2 = 6.67%, topic 3 = 6.67%
# Document 18195 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18196 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 18197 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18198 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18199 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18200 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18201 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18202 has the following percent of each topic 1 =  3.33%,        topic 2 = 53.33%, topic 3 = 3.33%
# Document 18203 has the following percent of each topic 1 =  1.33%,        topic 2 = 21.33%, topic 3 = 1.33%
# Document 18204 has the following percent of each topic 1 =  1.11%,        topic 2 = 1.11%, topic 3 = 1.11%
# Document 18205 has the following percent of each topic 1 =  1.67%,        topic 2 = 1.67%, topic 3 = 1.67%
# Document 18206 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# Document 18207 has the following percent of each topic 1 =  1.33%,        topic 2 = 1.33%, topic 3 = 21.33%
# Document 18208 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18209 has the following percent of each topic 1 =  1.67%,        topic 2 = 26.67%, topic 3 = 1.67%
# Document 18210 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18211 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 2.22%
# Document 18212 has the following percent of each topic 1 =  1.11%,        topic 2 = 17.78%, topic 3 = 1.11%
# Document 18213 has the following percent of each topic 1 =  22.96%,        topic 2 = 11.85%, topic 3 = 0.74%
# Document 18214 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18215 has the following percent of each topic 1 =  3.33%,        topic 2 = 3.33%, topic 3 = 3.33%
# Document 18216 has the following percent of each topic 1 =  2.22%,        topic 2 = 2.22%, topic 3 = 35.56%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-e64853b3fbf4> in <module>()
# ----> 1 display_percent_of_each_topic(lda_W,lda_model,tf_feature_names, 10)
#
# <ipython-input-78-05aae32d0e53> in display_percent_of_each_topic(lda_W, model, feature_names, no_top_words)
#       4     """
#       5     for topic_idx, topic in enumerate(lda_W):
# ----> 6         print(f"""Document {topic_idx} has the following percent of each topic 1 =  {topic[0]:.2%},        topic 2 = {topic[1]:.2%}, topic 3 = {topic[2]:.2%}""")
#       7
#       8     print()
#
# /Users/jonathanhilgart/anaconda/envs/nlp_founder/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# /Users/jonathanhilgart/anaconda/envs/nlp_founder/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     188                 event_id = os.urandom(16)
#     189             self._events[event_id] = f
# --> 190             self._event_pipe.send(event_id)
#     191         else:
#     192             f()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq/backend/cython/socket.c:7305)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq/backend/cython/socket.c:7048)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy (zmq/backend/cython/socket.c:2920)()
#
# /Users/jonathanhilgart/anaconda/envs/nlp_founder/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:

# %%
doc_set
# Out:
# ['Brocolli is good to eat. My brother likes to eat good brocolli, but not my mother. It helps you with heart problems.',
#  'My mother spends a lot of time driving my brother around to baseball practice. Baseball if one of my brothers favorite activities',
#  'Some health experts suggest that driving may cause increased tension and blood pressure. Also, driving may cause skin cancer.',
#  'I often feel pressure to perform well at school, but my mother never seems to drive my brother to do better.',
#  'Health professionals say that brocolli is good for your health. It can also counter the negatives of stress.']

# %%
# Test random forest with text - need to conver to categorical representation

# %%
df_train = pd.DataFrame({'niche':['software','hardware','software','software'],
                  'employees':[1,4,3,4],'service_level':['gold','silver','gold','bronze'],
                        'revenue':[123,321,14,234],})

# %%
df_train = pd.get_dummies( df_train,drop_first=True)

# %%
df_train
# Out:
#    employees  revenue  niche_hardware  niche_software  service_level_bronze  \
# 0          1      123               0               1                     0
# 1          4      321               1               0                     0
# 2          3       14               0               1                     0
# 3          4      234               0               1                     1
#
#    service_level_gold  service_level_silver
# 0                   1                     0
# 1                   0                     1
# 2                   1                     0
# 3                   0                     0

# %%
rf=  RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X = df_train.loc[:,('employees', 'niche_hardware','niche_software','service_level_bronze',
                          'service_level_gold','service_level_silver')], y= df_train.revenue)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
rf.predict(np.array([[1,10,1,0,0,1]]))
# Out:
# array([ 206.58])

# %% [markdown]
# # Founder Topic Model
# - Get all text from all founders

# %%
vc_zero_tweets = os.listdir("../data/raw/founders_tweets/vc_invest=0/")

# %%
mypath_vc_zero  = "../data/raw/founders_tweets/vc_invest=0/"
mypath_vc_one = "../data/raw/founders_tweets/vc_invest=1/"

# %%
print(len(listdir(mypath_vc_zero))) # vc invest zero companies
# Out:
# 92

# %%
print(len(listdir(mypath_vc_one))) # vc invest one companies
# Out:
# 123

# %%
r = ['here','now','there']

# %%
r.index('now')
# Out:
# 1

# %%
vc_doc_list = []
vc_founder_company_name_handle_list = [] # founder names index corresponds to their doc in the vc doc list

# vc invest one
for f in listdir(mypath_vc_zero):

    if isfile(join(mypath_vc_zero, f)):
        founder_text = ""
        with open(join(mypath_vc_zero, f),'rb') as fp:
            founder_tweet = pickle.load(fp)
            joined_text = founder_text.join(founder_tweet )
            vc_doc_list.append(joined_text)
            vc_founder_company_name_handle_list.append(f)

            
# vc invest zero
for f in listdir(mypath_vc_one):
    if isfile(join(mypath_vc_one, f)):
        founder_text = ""
        with open(join(mypath_vc_one, f),'rb') as fp:
            founder_tweet = pickle.load(fp)
            joined_text = founder_text.join(founder_tweet )
            vc_doc_list.append(joined_text)
            vc_founder_company_name_handle_list.append(f)

# %%
len(vc_doc_list) # total number of companies
# Out:
# 215

# %% [markdown]
# ## Fit an LDA model

# %%
no_features=1_000

# %%
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=1, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(vc_doc_list)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
lda_model = LatentDirichletAllocation(n_topics=5, max_iter=5, 
                                      learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
lda_W = lda_model.transform(tf) # documents as the rows, topics as the columns
lda_H = lda_model.components_ # topics as the rows, words as the columns

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
no_top_words = 15

display_topics(lda_model, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# la en pour khan amir et le est je au du une tu pas på
# Topic 1:
# new favorite organic wise cancer thanks iorganic help connecting amp remix free love just isoflow
# Topic 2:
# amp crowdfunding great new data conference don just cloud year free marketing webinar check miss
# Topic 3:
# just new like amp day today time great good love thanks don know people best
# Topic 4:
# woopra thanks lethalweapon amp just fresno new diversity great love summer thank like don know

# %% [markdown]
# ## Determine the percent of each topic per founder

# %%
def return_percent_of_topic(lda_W):
    c = 0
    for topic_idx, topic in enumerate(lda_W):
        for topic_percent in range(len(topic)):
            print(f"""Document {topic_idx} has the following percent of each topic  =  {topic[topic_percent]:.2%}""")
            c +=1
            if c ==10:
                break

# %%
return_percent_of_topic(lda_W)
# Out:
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  61.36%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.00%
# Document 0 has the following percent of each topic  =  0.05%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  0.21%
# Document 1 has the following percent of each topic  =  97.08%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  0.00%
# Document 2 has the following percent of each topic  =  99.99%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  84.43%
# Document 3 has the following percent of each topic  =  5.14%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  0.03%
# Document 3 has the following percent of each topic  =  10.04%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  30.04%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  0.00%
# Document 4 has the following percent of each topic  =  69.96%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  78.37%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  0.02%
# Document 5 has the following percent of each topic  =  21.35%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  74.25%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  0.02%
# Document 6 has the following percent of each topic  =  25.54%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  94.81%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 7 has the following percent of each topic  =  0.37%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  0.04%
# Document 8 has the following percent of each topic  =  99.50%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  36.50%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  0.02%
# Document 9 has the following percent of each topic  =  63.22%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  30.60%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  0.19%
# Document 10 has the following percent of each topic  =  66.99%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  0.00%
# Document 11 has the following percent of each topic  =  99.99%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  0.00%
# Document 12 has the following percent of each topic  =  99.99%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  47.96%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  0.00%
# Document 13 has the following percent of each topic  =  52.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  1.11%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  0.00%
# Document 14 has the following percent of each topic  =  98.89%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  0.00%
# Document 15 has the following percent of each topic  =  99.98%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  0.00%
# Document 16 has the following percent of each topic  =  99.99%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  0.02%
# Document 17 has the following percent of each topic  =  99.71%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  86.99%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  0.00%
# Document 18 has the following percent of each topic  =  13.00%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  0.02%
# Document 19 has the following percent of each topic  =  99.74%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  22.91%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  0.00%
# Document 20 has the following percent of each topic  =  77.06%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 21 has the following percent of each topic  =  6.67%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  81.16%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  0.02%
# Document 22 has the following percent of each topic  =  18.62%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  0.02%
# Document 23 has the following percent of each topic  =  99.67%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  30.80%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  0.04%
# Document 24 has the following percent of each topic  =  68.67%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  0.00%
# Document 25 has the following percent of each topic  =  99.99%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  0.00%
# Document 26 has the following percent of each topic  =  99.99%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  0.21%
# Document 27 has the following percent of each topic  =  97.08%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  0.00%
# Document 28 has the following percent of each topic  =  99.98%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  99.99%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 29 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.18%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  0.00%
# Document 30 has the following percent of each topic  =  99.80%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  0.06%
# Document 31 has the following percent of each topic  =  99.12%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  81.54%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  0.00%
# Document 32 has the following percent of each topic  =  18.45%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  25.35%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  0.00%
# Document 33 has the following percent of each topic  =  74.64%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  35.33%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  0.04%
# Document 34 has the following percent of each topic  =  64.09%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  0.08%
# Document 35 has the following percent of each topic  =  98.94%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  10.41%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  77.15%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  0.00%
# Document 36 has the following percent of each topic  =  12.43%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  63.28%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  1.78%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  0.00%
# Document 37 has the following percent of each topic  =  34.89%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  0.00%
# Document 38 has the following percent of each topic  =  99.97%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  37.08%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  0.03%
# Document 39 has the following percent of each topic  =  62.56%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  17.20%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  0.00%
# Document 40 has the following percent of each topic  =  82.78%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  100.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 41 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  0.00%
# Document 42 has the following percent of each topic  =  99.97%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  0.00%
# Document 43 has the following percent of each topic  =  99.94%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  0.00%
# Document 44 has the following percent of each topic  =  99.99%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  1.67%
# Document 45 has the following percent of each topic  =  76.67%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.01%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  99.17%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.00%
# Document 46 has the following percent of each topic  =  0.82%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  99.99%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 47 has the following percent of each topic  =  0.00%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  45.92%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  13.85%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  0.01%
# Document 48 has the following percent of each topic  =  40.13%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  99.81%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 49 has the following percent of each topic  =  0.01%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  87.93%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  9.84%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 50 has the following percent of each topic  =  0.17%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  54.03%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  0.01%
# Document 51 has the following percent of each topic  =  45.79%
# ...
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  0.00%
# Document 198 has the following percent of each topic  =  99.98%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  0.00%
# Document 199 has the following percent of each topic  =  99.99%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  65.61%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  0.01%
# Document 200 has the following percent of each topic  =  34.31%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  66.49%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  0.01%
# Document 201 has the following percent of each topic  =  33.41%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  7.24%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  0.00%
# Document 202 has the following percent of each topic  =  92.74%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  39.29%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  0.03%
# Document 203 has the following percent of each topic  =  60.32%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  0.00%
# Document 204 has the following percent of each topic  =  99.99%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  99.99%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 205 has the following percent of each topic  =  0.00%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  99.89%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 206 has the following percent of each topic  =  0.01%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  47.29%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  0.00%
# Document 207 has the following percent of each topic  =  52.70%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  0.00%
# Document 208 has the following percent of each topic  =  99.99%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  99.52%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.00%
# Document 209 has the following percent of each topic  =  0.43%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  90.53%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  1.79%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  0.01%
# Document 210 has the following percent of each topic  =  7.59%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.70%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  0.00%
# Document 211 has the following percent of each topic  =  99.29%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  36.73%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  0.01%
# Document 212 has the following percent of each topic  =  63.12%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  0.01%
# Document 213 has the following percent of each topic  =  99.91%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  98.44%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
# Document 214 has the following percent of each topic  =  0.11%
