# %%
import requests
import json

# %%
# people end point
params_ppl_endpoint = {'user_key': '5946a65c14f2e13eac86a78548e13d92','organization_name':'BitInstant'}
ppl = requests.get('https://api.crunchbase.com/v/3/odm-people',
                 params=params_ppl_endpoint)

# %%
#The ODM can be accessed through /odm-organizations and /odm-people collection endpoints in the REST API.

# %%
ppl.json()['data'] # has organization name
# Out:
# {'items': [{'properties': {'api_path': 'people/brig-graff',
#     'city_name': 'Salt Lake City',
#     'country_code': 'USA',
#     'created_at': 1497290333,
#     'facebook_url': None,
#     'first_name': 'Brig',
#     'gender': 'Male',
#     'homepage_url': None,
#     'last_name': 'Graff',
#     'linkedin_url': None,
#     'organization_api_path': 'organizations/zignal-labs',
#     'organization_name': 'Zignal Labs',
#     'organization_permalink': 'zignal-labs',
#     'organization_web_path': 'organization/zignal-labs',
#     'permalink': 'brig-graff',
#     'profile_image_url': 'http://public.crunchbase.com/t_api_images/v1497290254/wdq0skniy559q926vptk.jpg',
#     'region_name': 'Utah',
#     'title': 'VP of Strategic Solutions',
#     'twitter_url': None,
#     'updated_at': 1497290334,
#     'web_path': 'person/brig-graff'},
#    'type': 'Person',
#    'uuid': '3739d5dc741827ea423bd0bf5945753f'},
#   {'properties': {'api_path': 'people/tammie-presser',
# ...

# %%
# organization end point
params_org_endpoint = {'user_key': '5946a65c14f2e13eac86a78548e13d92'}
org = requests.get('https://api.crunchbase.com/v/3/odm-organizations',
                 params=params_org_endpoint)

# %%
org.json()['data'].keys()
# Out:
# dict_keys(['paging', 'items'])

# %%
org.json()['data']
# Out:
# {'items': [{'properties': {'api_path': 'organizations/mwdn',
#     'city_name': None,
#     'country_code': None,
#     'created_at': 1497289914,
#     'domain': 'mwdn.com',
#     'facebook_url': None,
#     'homepage_url': 'https://mwdn.com',
#     'linkedin_url': None,
#     'name': 'MWDN',
#     'permalink': 'mwdn',
#     'primary_role': 'company',
#     'profile_image_url': 'http://public.crunchbase.com/t_api_images/v1497289902/n0ziuy9njcuntgj6khej.png',
#     'region_name': None,
#     'short_description': 'Outsourcing Software Development Company',
#     'twitter_url': None,
#     'updated_at': 1497290081,
#     'web_path': 'organization/mwdn'},
#    'type': 'OrganizationSummary',
#    'uuid': '10b841bfbc9fcda329e2b7983e244fca'},
#   {'properties': {'api_path': 'organizations/fridom-com-br-2',
#     'city_name': None,
#     'country_code': None,
#     'created_at': 1497289910,
#     'domain': None,
#     'facebook_url': None,
#     'homepage_url': None,
# ...
